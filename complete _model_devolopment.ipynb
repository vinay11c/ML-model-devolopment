# %%
from sklearn.datasets import  fetch_california_housing
from sklearn import datasets
dir(datasets)

# %%
from sklearn.datasets import  fetch_california_housing
california=fetch_california_housing()
california
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
california.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
california['data'][0]
# Out:
# array([   8.3252    ,   41.        ,    6.98412698,    1.02380952,
#         322.        ,    2.55555556,   37.88      , -122.23      ])

# %%
california['data'].shape
# Out:
# (20640, 8)

# %%
california['data'][0].shape
# Out:
# (8,)

# %%
california['target'].shape # here only the row is coming but not columns means it is the output column
# Out:
# (20640,)

# %%
california['target_names']
# Out:
# ['MedHouseVal']

# %%
import pandas as pd
col=[california['feature_names']]
calfornia_df=pd.DataFrame(california['data'],columns=col)
calfornia_df[california['target_names'][0]]=california['target']
calfornia_df
# Out:
#        MedInc HouseAge  AveRooms AveBedrms Population  AveOccup Latitude  \
# 0      8.3252     41.0  6.984127  1.023810      322.0  2.555556    37.88
# 1      8.3014     21.0  6.238137  0.971880     2401.0  2.109842    37.86
# 2      7.2574     52.0  8.288136  1.073446      496.0  2.802260    37.85
# 3      5.6431     52.0  5.817352  1.073059      558.0  2.547945    37.85
# 4      3.8462     52.0  6.281853  1.081081      565.0  2.181467    37.85
# ...       ...      ...       ...       ...        ...       ...      ...
# 20635  1.5603     25.0  5.045455  1.133333      845.0  2.560606    39.48
# 20636  2.5568     18.0  6.114035  1.315789      356.0  3.122807    39.49
# 20637  1.7000     17.0  5.205543  1.120092     1007.0  2.325635    39.43
# 20638  1.8672     18.0  5.329513  1.171920      741.0  2.123209    39.43
# 20639  2.3886     16.0  5.254717  1.162264     1387.0  2.616981    39.37
#
#       Longitude MedHouseVal
# 0       -122.23       4.526
# 1       -122.22       3.585
# ...

# %%
california
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %% [markdown]
# **End to End model devolopment**

# %% [markdown]
# **Scaling of data**

# %%
X=calfornia_df.drop(['MedHouseVal'],axis=1)
y=calfornia_df['MedHouseVal']
# Out:
# C:\Users\VINAY\AppData\Local\Temp\ipykernel_14252\1421207812.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X=calfornia_df.drop(['MedHouseVal'],axis=1)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
scaled=ss.fit_transform(X)
scaled
# Out:
# array([[ 2.34476576,  0.98214266,  0.62855945, ..., -0.04959654,
#          1.05254828, -1.32783522],
#        [ 2.33223796, -0.60701891,  0.32704136, ..., -0.09251223,
#          1.04318455, -1.32284391],
#        [ 1.7826994 ,  1.85618152,  1.15562047, ..., -0.02584253,
#          1.03850269, -1.33282653],
#        ...,
#        [-1.14259331, -0.92485123, -0.09031802, ..., -0.0717345 ,
#          1.77823747, -0.8237132 ],
#        [-1.05458292, -0.84539315, -0.04021111, ..., -0.09122515,
#          1.77823747, -0.87362627],
#        [-0.78012947, -1.00430931, -0.07044252, ..., -0.04368215,
#          1.75014627, -0.83369581]])

# %%
scaled_df=pd.DataFrame(scaled,columns=X.columns)
scaled_df['MedHouseVal']=y
scaled_df
# Out:
#          MedInc  HouseAge  AveRooms AveBedrms Population  AveOccup  Latitude  \
# 0      2.344766  0.982143  0.628559 -0.153758  -0.974429 -0.049597  1.052548
# 1      2.332238 -0.607019  0.327041 -0.263336   0.861439 -0.092512  1.043185
# 2      1.782699  1.856182  1.155620 -0.049016  -0.820777 -0.025843  1.038503
# 3      0.932968  1.856182  0.156966 -0.049833  -0.766028 -0.050329  1.038503
# 4     -0.012881  1.856182  0.344711 -0.032906  -0.759847 -0.085616  1.038503
# ...         ...       ...       ...       ...        ...       ...       ...
# 20635 -1.216128 -0.289187 -0.155023  0.077354  -0.512592 -0.049110  1.801647
# 20636 -0.691593 -0.845393  0.276881  0.462365  -0.944405  0.005021  1.806329
# 20637 -1.142593 -0.924851 -0.090318  0.049414  -0.369537 -0.071735  1.778237
# 20638 -1.054583 -0.845393 -0.040211  0.158778  -0.604429 -0.091225  1.778237
# 20639 -0.780129 -1.004309 -0.070443  0.138403  -0.033977 -0.043682  1.750146
#
#       Longitude MedHouseVal
# ...

# %% [markdown]
# **Correlation plot**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
scaled_df
# Out:
#          MedInc  HouseAge  AveRooms AveBedrms Population  AveOccup  Latitude  \
# 0      2.344766  0.982143  0.628559 -0.153758  -0.974429 -0.049597  1.052548
# 1      2.332238 -0.607019  0.327041 -0.263336   0.861439 -0.092512  1.043185
# 2      1.782699  1.856182  1.155620 -0.049016  -0.820777 -0.025843  1.038503
# 3      0.932968  1.856182  0.156966 -0.049833  -0.766028 -0.050329  1.038503
# 4     -0.012881  1.856182  0.344711 -0.032906  -0.759847 -0.085616  1.038503
# ...         ...       ...       ...       ...        ...       ...       ...
# 20635 -1.216128 -0.289187 -0.155023  0.077354  -0.512592 -0.049110  1.801647
# 20636 -0.691593 -0.845393  0.276881  0.462365  -0.944405  0.005021  1.806329
# 20637 -1.142593 -0.924851 -0.090318  0.049414  -0.369537 -0.071735  1.778237
# 20638 -1.054583 -0.845393 -0.040211  0.158778  -0.604429 -0.091225  1.778237
# 20639 -0.780129 -1.004309 -0.070443  0.138403  -0.033977 -0.043682  1.750146
#
#       Longitude MedHouseVal
# ...

# %%
plt.figure(figsize=(10,6))
corr=scaled_df.corr()
sns.heatmap(corr,annot=True)
plt.show()

# %%
plt.scatter(scaled_df['Latitude'],scaled_df['Longitude'])
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,3,1).scatter(scaled_df["AveRooms"], scaled_df["AveBedrms"])
plt.subplot(1,3,2).scatter(scaled_df['Latitude'],scaled_df["Longitude"])
plt.subplot(1,3,3).scatter(scaled_df['Population'], scaled_df["MedInc"])

plt.show()

# %%
scaled_df
# Out:
#          MedInc  HouseAge  AveRooms AveBedrms Population  AveOccup  Latitude  \
# 0      2.344766  0.982143  0.628559 -0.153758  -0.974429 -0.049597  1.052548
# 1      2.332238 -0.607019  0.327041 -0.263336   0.861439 -0.092512  1.043185
# 2      1.782699  1.856182  1.155620 -0.049016  -0.820777 -0.025843  1.038503
# 3      0.932968  1.856182  0.156966 -0.049833  -0.766028 -0.050329  1.038503
# 4     -0.012881  1.856182  0.344711 -0.032906  -0.759847 -0.085616  1.038503
# ...         ...       ...       ...       ...        ...       ...       ...
# 20635 -1.216128 -0.289187 -0.155023  0.077354  -0.512592 -0.049110  1.801647
# 20636 -0.691593 -0.845393  0.276881  0.462365  -0.944405  0.005021  1.806329
# 20637 -1.142593 -0.924851 -0.090318  0.049414  -0.369537 -0.071735  1.778237
# 20638 -1.054583 -0.845393 -0.040211  0.158778  -0.604429 -0.091225  1.778237
# 20639 -0.780129 -1.004309 -0.070443  0.138403  -0.033977 -0.043682  1.750146
#
#       Longitude MedHouseVal
# ...

# %% [markdown]
# **VIF on scaled data**

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# exogenious = input variable
# variance_inflation_factor(,)

# %%
X=calfornia_df.drop(['MedHouseVal'],axis=1,level=0)
y=calfornia_df['MedHouseVal']
X.columns
# Out:
# MultiIndex([(    'MedInc',),
#             (  'HouseAge',),
#             (  'AveRooms',),
#             ( 'AveBedrms',),
#             ('Population',),
#             (  'AveOccup',),
#             (  'Latitude',),
#             ( 'Longitude',)],
#            )

# %%
vif_scale=[]
for i in range (len(X.columns)):
    vif_scale.append(variance_inflation_factor(scaled,i))
vif_scale
# Out:
# [2.501294512541596,
#  1.2412541182182888,
#  8.342785615374497,
#  6.994994771360948,
#  1.1381250818336015,
#  1.008324448980445,
#  9.297624369314345,
#  8.96226347381993]

# %%
vif_scaled_df=pd.DataFrame(vif_scale,index=X.columns,columns=['VIF'])
vif_scaled_df.sort_values(by='VIF',ascending=False)
# Out:
#                  VIF
# Latitude    9.297624
# Longitude   8.962263
# AveRooms    8.342786
# AveBedrms   6.994995
# MedInc      2.501295
# HouseAge    1.241254
# Population  1.138125
# AveOccup    1.008324

# %% [markdown]
# Case-2
# - Read the main data
# - perform the vif on main data

# %%
calfornia_df
# Out:
#        MedInc HouseAge  AveRooms AveBedrms Population  AveOccup Latitude  \
# 0      8.3252     41.0  6.984127  1.023810      322.0  2.555556    37.88
# 1      8.3014     21.0  6.238137  0.971880     2401.0  2.109842    37.86
# 2      7.2574     52.0  8.288136  1.073446      496.0  2.802260    37.85
# 3      5.6431     52.0  5.817352  1.073059      558.0  2.547945    37.85
# 4      3.8462     52.0  6.281853  1.081081      565.0  2.181467    37.85
# ...       ...      ...       ...       ...        ...       ...      ...
# 20635  1.5603     25.0  5.045455  1.133333      845.0  2.560606    39.48
# 20636  2.5568     18.0  6.114035  1.315789      356.0  3.122807    39.49
# 20637  1.7000     17.0  5.205543  1.120092     1007.0  2.325635    39.43
# 20638  1.8672     18.0  5.329513  1.171920      741.0  2.123209    39.43
# 20639  2.3886     16.0  5.254717  1.162264     1387.0  2.616981    39.37
#
#       Longitude MedHouseVal
# 0       -122.23       4.526
# 1       -122.22       3.585
# ...

# %%
X=calfornia_df.drop('MedHouseVal',axis=1,level=0)
y=calfornia_df['MedHouseVal']
X
# Out:
#        MedInc HouseAge  AveRooms AveBedrms Population  AveOccup Latitude  \
# 0      8.3252     41.0  6.984127  1.023810      322.0  2.555556    37.88
# 1      8.3014     21.0  6.238137  0.971880     2401.0  2.109842    37.86
# 2      7.2574     52.0  8.288136  1.073446      496.0  2.802260    37.85
# 3      5.6431     52.0  5.817352  1.073059      558.0  2.547945    37.85
# 4      3.8462     52.0  6.281853  1.081081      565.0  2.181467    37.85
# ...       ...      ...       ...       ...        ...       ...      ...
# 20635  1.5603     25.0  5.045455  1.133333      845.0  2.560606    39.48
# 20636  2.5568     18.0  6.114035  1.315789      356.0  3.122807    39.49
# 20637  1.7000     17.0  5.205543  1.120092     1007.0  2.325635    39.43
# 20638  1.8672     18.0  5.329513  1.171920      741.0  2.123209    39.43
# 20639  2.3886     16.0  5.254717  1.162264     1387.0  2.616981    39.37
#
#       Longitude
# 0       -122.23
# 1       -122.22
# 2       -122.24
# 3       -122.25
# ...

# %%
X.values  # convert to array format
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]])

# %%
vif_main=[]
for i in range (len(X.columns)):
    vif_main.append(variance_inflation_factor(X.values,i))
vif_main
# Out:
# [11.511140059486932,
#  7.195917300645759,
#  45.99360103802389,
#  43.59031403163056,
#  2.935745199687898,
#  1.0952432155971747,
#  559.8740713791312,
#  633.7116543669108]

# %%
vif_main_df=pd.DataFrame(vif_main,index=X.columns,columns=['VIF'])
vif_main_df.sort_values(by='VIF',ascending=False)
# Out:
#                    VIF
# Longitude   633.711654
# Latitude    559.874071
# AveRooms     45.993601
# AveBedrms    43.590314
# MedInc       11.511140
# HouseAge      7.195917
# Population    2.935745
# AveOccup      1.095243

# %%
cols1=vif_main_df[vif_main_df['VIF']<15].reset_index()['level_0'].tolist()
cols1
# Out:
# ['MedInc', 'HouseAge', 'Population', 'AveOccup']

# %% [markdown]
# Selecting Final Columns

# %%
cols=vif_main_df[vif_main_df['VIF']<15].index
cols
# Out:
# MultiIndex([(    'MedInc',),
#             (  'HouseAge',),
#             ('Population',),
#             (  'AveOccup',)],
#            )

# %%
cols1=vif_main_df[vif_main_df['VIF']<15].reset_index()['level_0'].tolist()
cols1
# Out:
# ['MedInc', 'HouseAge', 'Population', 'AveOccup']

# %%
cols2=vif_main_df[vif_main_df['VIF']>15].reset_index()['level_0'].tolist()
cols2
# Out:
# ['AveRooms', 'AveBedrms', 'Latitude', 'Longitude']

# %%
cols2=['AveRooms','Latitude']
final_cols=cols1+cols2
final_cols
# Out:
# ['MedInc', 'HouseAge', 'Population', 'AveOccup', 'AveRooms', 'Latitude']

# %%
calfornia_df
# Out:
#        MedInc HouseAge  AveRooms AveBedrms Population  AveOccup Latitude  \
# 0      8.3252     41.0  6.984127  1.023810      322.0  2.555556    37.88
# 1      8.3014     21.0  6.238137  0.971880     2401.0  2.109842    37.86
# 2      7.2574     52.0  8.288136  1.073446      496.0  2.802260    37.85
# 3      5.6431     52.0  5.817352  1.073059      558.0  2.547945    37.85
# 4      3.8462     52.0  6.281853  1.081081      565.0  2.181467    37.85
# ...       ...      ...       ...       ...        ...       ...      ...
# 20635  1.5603     25.0  5.045455  1.133333      845.0  2.560606    39.48
# 20636  2.5568     18.0  6.114035  1.315789      356.0  3.122807    39.49
# 20637  1.7000     17.0  5.205543  1.120092     1007.0  2.325635    39.43
# 20638  1.8672     18.0  5.329513  1.171920      741.0  2.123209    39.43
# 20639  2.3886     16.0  5.254717  1.162264     1387.0  2.616981    39.37
#
#       Longitude MedHouseVal
# 0       -122.23       4.526
# 1       -122.22       3.585
# ...

# %%
y
# Out:
#       MedHouseVal
# 0           4.526
# 1           3.585
# 2           3.521
# 3           3.413
# 4           3.422
# ...           ...
# 20635       0.781
# 20636       0.771
# 20637       0.923
# 20638       0.847
# 20639       0.894
#
# [20640 rows x 1 columns]

# %%
final_df=calfornia_df[final_cols]
final_df['MedHouseVal']=y
final_df
# Out:
# C:\Users\VINAY\AppData\Local\Temp\ipykernel_14252\2690260646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['MedHouseVal']=y
#        MedInc HouseAge Population  AveOccup  AveRooms Latitude MedHouseVal
# 0      8.3252     41.0      322.0  2.555556  6.984127    37.88       4.526
# 1      8.3014     21.0     2401.0  2.109842  6.238137    37.86       3.585
# 2      7.2574     52.0      496.0  2.802260  8.288136    37.85       3.521
# 3      5.6431     52.0      558.0  2.547945  5.817352    37.85       3.413
# 4      3.8462     52.0      565.0  2.181467  6.281853    37.85       3.422
# ...       ...      ...        ...       ...       ...      ...         ...
# ...

# %%
final_df = calfornia_df[final_cols].copy()
final_df['MedHouseVal'] = y

# %%
final_df
# Out:
#        MedInc HouseAge Population  AveOccup  AveRooms Latitude MedHouseVal
# 0      8.3252     41.0      322.0  2.555556  6.984127    37.88       4.526
# 1      8.3014     21.0     2401.0  2.109842  6.238137    37.86       3.585
# 2      7.2574     52.0      496.0  2.802260  8.288136    37.85       3.521
# 3      5.6431     52.0      558.0  2.547945  5.817352    37.85       3.413
# 4      3.8462     52.0      565.0  2.181467  6.281853    37.85       3.422
# ...       ...      ...        ...       ...       ...      ...         ...
# 20635  1.5603     25.0      845.0  2.560606  5.045455    39.48       0.781
# 20636  2.5568     18.0      356.0  3.122807  6.114035    39.49       0.771
# 20637  1.7000     17.0     1007.0  2.325635  5.205543    39.43       0.923
# 20638  1.8672     18.0      741.0  2.123209  5.329513    39.43       0.847
# 20639  2.3886     16.0     1387.0  2.616981  5.254717    39.37       0.894
#
# [20640 rows x 7 columns]

# %% [markdown]
# - in linear regression scaling is very imp
# - non divide the final df into X and y
# - scale the X, and create a dataframe name it as X_scaled

# %%
# model devolopment
from sklearn.preprocessing import StandardScaler
import pandas as pd

ss=StandardScaler()
X_scaled=ss.fit_transform(X)
X_scaled_df=pd.DataFrame(X_scaled,columns=X.columns)
X_scaled_df
# Out:
#          MedInc  HouseAge  AveRooms AveBedrms Population  AveOccup  Latitude  \
# 0      2.344766  0.982143  0.628559 -0.153758  -0.974429 -0.049597  1.052548
# 1      2.332238 -0.607019  0.327041 -0.263336   0.861439 -0.092512  1.043185
# 2      1.782699  1.856182  1.155620 -0.049016  -0.820777 -0.025843  1.038503
# 3      0.932968  1.856182  0.156966 -0.049833  -0.766028 -0.050329  1.038503
# 4     -0.012881  1.856182  0.344711 -0.032906  -0.759847 -0.085616  1.038503
# ...         ...       ...       ...       ...        ...       ...       ...
# 20635 -1.216128 -0.289187 -0.155023  0.077354  -0.512592 -0.049110  1.801647
# 20636 -0.691593 -0.845393  0.276881  0.462365  -0.944405  0.005021  1.806329
# 20637 -1.142593 -0.924851 -0.090318  0.049414  -0.369537 -0.071735  1.778237
# 20638 -1.054583 -0.845393 -0.040211  0.158778  -0.604429 -0.091225  1.778237
# 20639 -0.780129 -1.004309 -0.070443  0.138403  -0.033977 -0.043682  1.750146
#
#       Longitude
# 0     -1.327835
# ...

# %% [markdown]
# **train test split**

# %% [markdown]
# package:sklearn
#
# class name: model selection
#
# method name: train_test_split
#
# - we need to provide x and y
# - we need to select test_sixe for example 0.2 means 20% of total data
# - **Random_state** we need to provide a number,selection of data will fixed( we will get rabdom data)
# - shuffle true indicates random data
# - it will give 4 outputs

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X_scaled_df,y,test_size=0.2,
                                                        random_state=1234)

# %% [markdown]
# **Checkpoint-1**
#
# - get all the shape
# - x_train and x_test inputs
# - final_df has 6 input columns
# - so x_train and x_test also has 6 columns
# - y_train shape  we cannot see a like x_train

# %%
X_scaled_df.shape,x_train.shape,x_test.shape
# Out:
# ((20640, 8), (16512, 8), (4128, 8))

# %%
y_train.shape,y_test.shape
# Out:
# ((16512, 1), (4128, 1))

# %% [markdown]
# **Checkpoint-2**
#
# - tally the size of data
# - 20% of total data(20640)=4128 that is sixe of test data
# - 80% of total data(20640)=

# %%
20*20640/100 # test data size
# Out:
# 4128.0

# %%
80*20640/100
# Out:
# 16512.0

# %%
#x_train (16512,6)
#x_test (4128,6)
#y_train (16512,)
# y_test(4128,)

# %% [markdown]
# **Checkpoint-3**
#
# - x_train has inputs corresponding output is y_train
# - x_test data has inputs correspondig output is y_test
# - so x_train and y_train index should match
# - x_test and y_test index should match

# %%
y_train.index
# Out:
# Index([17595,  6073,  6251,  3161,  1887,   151,  8888,  6273,  7383, 19964,
#        ...
#        13686,  7962,  8060,  7916,  1182,  8222,  9449,  8471, 17048,  1318],
#       dtype='int64', length=16512)

# %%
x_test.index
# Out:
# Index([15712,  4119, 15725, 14616, 13238,   256,  6689,  4123,  2287, 19689,
#        ...
#        20250, 15138, 10418, 16413, 13807, 13521, 16913, 20069,   446,  2209],
#       dtype='int64', length=4128)

# %%
y_test.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 y_test.index
#
# NameError: name 'y_test' is not defined

# %%
x_train.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 x_train.index
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# **Devolop the model**

# %% [markdown]
# package: sklearn
#
# class name: linear_model
#
# method name: LinerRegression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from sklearn.linear_model import LinearRegression
#       2 lr=LinearRegression()
# ----> 3 lr.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# **Predictions**

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 y_pred=lr.predict(x_test)
#       2 y_pred
#
# NameError: name 'lr' is not defined

# %%
len(y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(y_pred)
#
# NameError: name 'y_pred' is not defined

# %% [markdown]
# **Coeffiecients**

# %%
lr.coef_
# Out:
# array([[ 0.82855127,  0.11946997, -0.26585471,  0.28883839, -0.00625109,
#         -0.0409833 , -0.8805536 , -0.85340055]])

# %% [markdown]
# **Intercept**

# %%
lr.intercept_
# Out:
# array([2.06524031])

# %%
X.columns
# Out:
# MultiIndex([(    'MedInc',),
#             (  'HouseAge',),
#             (  'AveRooms',),
#             ( 'AveBedrms',),
#             ('Population',),
#             (  'AveOccup',),
#             (  'Latitude',),
#             ( 'Longitude',)],
#            )

# %%
MedHouseVal=bo+b1*'MedInc'+b2*'HouseAge'+b3*'AveRooms'+b4*
            'AveBedrms'+b5*'Population'+b6*'AveOccup'+b7*'Latitude'
MedHouseVal=2.06441711696833+0.832*MedInc+
# Out:
#   Cell In[110], line 1
#     MedHouseVal=bo+b1*'MedInc'+b2*'HouseAge'+b3*'AveRooms'+b4*
#                                                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# - now take x_test first sample
# - it has 6 values
# - substitute those 6 values in above equation we will get one answer
# -

# %%
x_test
# Out:
#          MedInc  HouseAge  AveRooms AveBedrms Population  AveOccup  Latitude  \
# 15712 -0.099733  1.856182 -0.234704 -0.038032  -0.716577 -0.129594  1.010411
# 4119   0.885225  1.856182  0.282943 -0.115509   0.367812 -0.009598 -0.698469
# 15725  0.002279  1.220517 -0.278781 -0.152216  -0.763379 -0.129966  1.005730
# 14616 -0.210589 -0.686477 -0.062546 -0.133136   0.350151  0.031639 -1.325839
# 13238  2.027992 -1.481058  1.045992 -0.162391  -0.180564  0.035508 -0.703151
# ...         ...       ...       ...       ...        ...       ...       ...
# 13521  0.703519 -0.686477  0.299587 -0.282569  -0.779274 -0.017558 -0.651651
# 16913  5.011449 -0.289187  1.390417 -0.145384   0.071989 -0.007758  0.898047
# 20069 -0.699541  0.108104 -0.138627  0.159038  -1.045073 -0.045110  1.113413
# 446    0.002279  1.856182 -0.421058 -0.266063  -0.917913 -0.113472  1.047866
# 2209  -0.060887 -1.083767 -0.026645 -0.301391  -0.366005  0.003862  0.551589
#
#       Longitude
# 15712 -1.432653
# ...

# %%
y_test
# Out:
#       MedHouseVal
# 15712     5.00000
# 4119      2.93900
# 15725     4.12500
# 14616     1.57600
# 13238     3.04100
# ...           ...
# 13521     1.64300
# 16913     5.00001
# 20069     1.23200
# 446       1.82600
# 2209      0.68000
#
# [4128 rows x 1 columns]

# %%
x_test.values[0]
# Out:
# array([-0.09973335,  1.85618152, -0.23470435, -0.03803226, -0.71657708,
#        -0.1295939 ,  1.01041149, -1.43265267])

# %%
import numpy as np
np.array([1,2,3])*np.array([3,4,5])
# Out:
# array([ 3,  8, 15])

# %%
lr.intercept_+np.sum(lr.coef_*x_test.values[0])
# Out:
# array([2.59847183])

# %%
x_test
# Out:
#          MedInc  HouseAge  AveRooms AveBedrms Population  AveOccup  Latitude  \
# 15712 -0.099733  1.856182 -0.234704 -0.038032  -0.716577 -0.129594  1.010411
# 4119   0.885225  1.856182  0.282943 -0.115509   0.367812 -0.009598 -0.698469
# 15725  0.002279  1.220517 -0.278781 -0.152216  -0.763379 -0.129966  1.005730
# 14616 -0.210589 -0.686477 -0.062546 -0.133136   0.350151  0.031639 -1.325839
# 13238  2.027992 -1.481058  1.045992 -0.162391  -0.180564  0.035508 -0.703151
# ...         ...       ...       ...       ...        ...       ...       ...
# 13521  0.703519 -0.686477  0.299587 -0.282569  -0.779274 -0.017558 -0.651651
# 16913  5.011449 -0.289187  1.390417 -0.145384   0.071989 -0.007758  0.898047
# 20069 -0.699541  0.108104 -0.138627  0.159038  -1.045073 -0.045110  1.113413
# 446    0.002279  1.856182 -0.421058 -0.266063  -0.917913 -0.113472  1.047866
# 2209  -0.060887 -1.083767 -0.026645 -0.301391  -0.366005  0.003862  0.551589
#
#       Longitude
# 15712 -1.432653
# ...

# %%
eval_df=x_test
eval_df['y_actual']=y_test
eval_df['y_pred']=y_pred
eval_df
# Out:
#          MedInc  HouseAge  AveRooms AveBedrms Population  AveOccup  Latitude  \
# 15712 -0.099733  1.856182 -0.234704 -0.038032  -0.716577 -0.129594  1.010411
# 4119   0.885225  1.856182  0.282943 -0.115509   0.367812 -0.009598 -0.698469
# 15725  0.002279  1.220517 -0.278781 -0.152216  -0.763379 -0.129966  1.005730
# 14616 -0.210589 -0.686477 -0.062546 -0.133136   0.350151  0.031639 -1.325839
# 13238  2.027992 -1.481058  1.045992 -0.162391  -0.180564  0.035508 -0.703151
# ...         ...       ...       ...       ...        ...       ...       ...
# 13521  0.703519 -0.686477  0.299587 -0.282569  -0.779274 -0.017558 -0.651651
# 16913  5.011449 -0.289187  1.390417 -0.145384   0.071989 -0.007758  0.898047
# 20069 -0.699541  0.108104 -0.138627  0.159038  -1.045073 -0.045110  1.113413
# 446    0.002279  1.856182 -0.421058 -0.266063  -0.917913 -0.113472  1.047866
# 2209  -0.060887 -1.083767 -0.026645 -0.301391  -0.366005  0.003862  0.551589
#
#       Longitude y_actual    y_pred
# ...

# %%
# creating one more columnn error
y_actual=eval_df['y_actual']
y_pred=eval_df['y_pred']
error=[i-j for i,j in zip(y_actual,y_pred)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[153], line 4
#       2 y_actual=eval_df['y_actual']
#       3 y_pred=eval_df['y_pred']
# ----> 4 error=[i-j for i,j in zip(y_actual,y_pred)]
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'tuple'

# %%
eval_df['y_actual'].values - eval_df['y_pred'].values
# Out:
# array([[nan],
#        [nan],
#        [nan],
#        ...,
#        [nan],
#        [nan],
#        [nan]])

# %%
**method-2**

# %%
y_pred=lr.predict(x_test)
y_test

# %%
error=eval_df['y_actual'].values-eval_df['y_pred'].values
square_error=np
np.sum(np.square(eval_df['y_actual'].values - eval_df['y_pred'].values))/len(eval_df)
# Out:
# nan

# %%
from sklearn .metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 0.5322341499776336

# %%
from sklearn .metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
R_square=r2_score(y_test,y_pred)
rmse=np.sqrt(mse)
print('Mse:',mse)
print('rmse:',rmse)
print('r2_score:',R_square)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[159], line 3
#       1 from sklearn .metrics import mean_squared_error
#       2 mse=mean_squared_error(y_test,y_pred)
# ----> 3 R_square=r2_score(y_test,y_pred)
#       4 rmse=np.sqrt(mse)
#       5 print('Mse:',mse)
#
# NameError: name 'r2_score' is not defined

# %%
**Pickle**

- it is similar to file handling session
- open('filename.txt','w')
- open('modelname.pk1','wb')
- in order to save we have method name: dump
- model_path_where_we_want_to_save
- pickle.dump(open('<model_name>.pk1','wb'),model_variable_name)

# %%
lr
# Out:
# LinearRegression()

# %%
import pickle
path=open('linear_regression_california.pk1','wb')
pickle.dump(path,lr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[169], line 3
#       1 import pickle
#       2 path=open('linear_regression_california.pk1','wb')
# ----> 3 pickle.dump(path,lr)
#
# TypeError: file must have a 'write' attribute

# %%
with open('linear_regression_california.pk1','wb')as file:
    pickle.dump(lr,file)

# %% [markdown]
# **Load the model**
#
# - pickle.load(path,'rb')

# %%
path=open('linear_regression_california.pk1','rb')
loaded_model=pickle.load(path)
loaded_model
# Out:
# LinearRegression()

# %% [markdown]
# **Prediction**

# %%
loaded_model.predict([[1,2,3,4,5,6,7,8]])
# Out:
# array([[-9.77771396]])

# %%
x_test.values
set1=[10,20,30,40,50,60,70,80]
set2=[1,2,3,4,5,6,7,8]
loaded_model.predict([set1,set2])
loaded_model.predict(x_test)

# %% [markdown]
# **Prediction**
#
# - we devoloped the model with 6 columns
# - so while providing the data we need to provide 6 values
# - there are two types of predictions
# - **Real time prediction**
# - application wise means we will pass a one sample at a time
# - **Batch prediction**
# - multiple sample values we need to pass to pass to the model it is same like x_test
